# %%
import ROOT
from ROOT import TObject, TH1F, array, TMath

#from root you can import TH1F whcih we will use to make histograms and other useful fucntions

# %jsroot on

f = ROOT.TFile.Open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/1lep/MC/mc_361103.Wminusenu.1lep.root")
#open tnhe open data files - start with the MC data for 1 lepton evetns in the W- --> e- nu decay

#create the plot space sing TCanvas
canvas=ROOT.TCanvas("Cavas","Transverse Momentum of e- vs Number of Events",800,600)

#create the empty histogram - transverse moemntum bins on the x axis/ frequency (number of events) on the y axis
hist = ROOT.TH1F("transmomhist","Transverse Momentum of Electrons ; Number of Events; Transverse Moentum of e- {GeV}",100,20,120)
#we will start the bins at 20 as the events are filtered so there is no transvers emomentum below 25GeV

#get data out of root file by defining the tree
tree=f.Get('mini')

#find out how many entries are contained within the tree 
tree.GetEntries()

#use the branch lep_pt to get the lepton transverse momentum
for event in tree:
    
    #print(event.lep_pt)
    hist.Fill(tree.lep_pt[0]/1000)
#divide by 1000 to get the momentum in to GeV

hist.Draw()
canvas.Draw()
# Out:
# Welcome to JupyROOT 6.26/08
# <div id="root_plot_1668685291305"
#      style="width: 796px; height: 572px">
# </div>
# <script>
#
# function display_root_plot_1668685291305(Core) {
#    let obj = Core.parse({"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":7.49999906867737,"fY1":-66088.4486739731,"fX2":132.500000931323,"fY2":594795.998673973,"fXtoAbsPixelk":-47.7599433576581,"fXtoPixelk":-47.7599433576581,"fXtoPixel":6.3679999051094,"fYtoAbsPixelk":514.800046590614,"fYtoPixelk":514.800046590614,"fYtoPixel":-8.65506825429726e-4,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":796,"fVtoAbsPixelk":572.00005,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":7.49999906867737,"fPixeltoXk":7.49999906867737,"fPixeltoX":0.157035178219404,"fAbsPixeltoYk":594795.998673973,"fPixeltoYk":-66088.4486739731,"fPixeltoY":-1155.39239046844,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":20,"fUymin":0,"fUxmax":120,"fUymax":528707.55,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":8,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":20,"fY1":0,"fX2":120,"fY2":528707.55,"fBorderSize":1,"fBorderMode":0},{"_typename":"TH1F","fUniqueID":0,"fBits":8,"fName":"transmomhist","fTitle":"Transverse Momentum of Electrons ","fLineColor":602,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNcells":102,"fXaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"xaxis","fTitle":" Number of Events","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":100,"fXmin":20,"fXmax":120,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fYaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"yaxis","fTitle":" Transverse Moentum of e- {GeV}","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":0,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fZaxis":{"_typename":"TAxis","fUniqueID":0,"fBits":0,"fName":"zaxis","fTitle":"","fNdivisions":510,"fAxisColor":1,"fLabelColor":1,"fLabelFont":42,"fLabelOffset":0.005,"fLabelSize":0.035,"fTickLength":0.03,"fTitleOffset":1,"fTitleSize":0.035,"fTitleColor":1,"fTitleFont":42,"fNbins":1,"fXmin":0,"fXmax":1,"fXbins":[],"fFirst":0,"fLast":0,"fBits2":0,"fTimeDisplay":false,"fTimeFormat":"","fLabels":null,"fModLabs":null},"fBarOffset":0,"fBarWidth":1000,"fEntries":9395683,"fTsumw":9344081,"fTsumw2":9344081,"fTsumwx":370266407.307039,"fTsumwx2":16063147478.2651,"fMaximum":-1111,"fMinimum":-1111,"fNormFactor":0,"fContour":[],"fSumw2":[],"fOption":"","fFunctions":{"_typename":"TList","name":"TList","arr":[{"_typename":"TPaveStats","fUniqueID":0,"fBits":9,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":105.000002533197,"fY1":446097.001959864,"fX2":130.000003278256,"fY2":551838.511172028,"fX1NDC":0.780000016093254,"fY1NDC":0.775000005960464,"fX2NDC":0.980000019073486,"fY2NDC":0.935000002384186,"fBorderSize":1,"fInit":1,"fShadowColor":1,"fCornerRadius": ...

# %%
#Next we can plot the transverse mass of the eldctron so get a vlaue of the W mass
#find the invariant mass and remove the z component

# %%
#using the same data set we can now fidn the invaiant mass of the electron evetns 
#define the lorentz vetors
electron=ROOT.TLorentzVector()

for events in tree:
# Out:
#   File "/tmp/ipykernel_684/1283695478.py", line 6
#
#     ^
# SyntaxError: unexpected EOF while parsing
